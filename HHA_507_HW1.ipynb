# %% [markdown]
# <a href="https://colab.research.google.com/github/Stephen-sanchez1/datasci_1_loading/blob/main/HHA_507_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Loading Packages

# %%
import pandas as pd
import json

# %% [markdown]
# ### Loading CSV Files

# %% [markdown]
# ##### CSV file #1
#
# ##### **Description of CSV file:** Mass shooting incidents in the United States in 2023.
#
#
# | Columns |  |
# |---|---|
# | Incident ID |  |
# | Incident date | |
# | State | |
# | City or county |  |
# | Address |  |
# | Victims killed |  |
# | Victims injured |  |
# | Suspects killed |  |
# | Suspects injured |  |
# | Suspects arrested |  |

# %%
#  CSV file #1
# Loading CSV file #1
dataset1 = pd.read_csv('/Mass_shootings_2023.csv')
dataset1.head(10)
# Out:
#    Incident ID      Incident Date           State City Or County  \
# 0      2699229  September 5, 2023        Illinois        Chicago
# 1      2698496  September 4, 2023         Alabama     Birmingham
# 2      2698171  September 3, 2023         Georgia        Atlanta
# 3      2698786  September 3, 2023  North Carolina     High Point
# 4      2698107  September 3, 2023           Texas      Galveston
# 5      2698160  September 3, 2023        Illinois       Freeport
# 6      2697278  September 2, 2023   Massachusetts           Lynn
# 7      2695977    August 30, 2023           Texas        Houston
# 8      2695354    August 30, 2023        Illinois         Peoria
# 9      2694245    August 29, 2023           Texas      Texarkana
#
#                          Address  Victims Killed  Victims Injured  \
# 0              4718 W Gladys Ave               0                4
# 1                  930 5th Ave N               2                3
# ...

# %% [markdown]
# ##### CSV file #2
#
# ##### **Description of CSV file:** Unintentional shooting incidents in the United States in 2023.
#
#
# | Columns |  |
# |---|---|
# | Incident ID |  |
# | Incident date | |
# | State | |
# | City or county |  |
# | Address |  |
# | Victims killed |  |
# | Victims injured |  |
# | Suspects killed |  |
# | Suspects injured |  |
# | Suspects arrested |  |

# %%
#  CSV file #2
# Loading CSV file #2
dataset2 = pd.read_csv('/Unintentional_shootings.csv')
dataset2.head(10)
# Out:
#    Incident ID      Incident Date           State City Or County  \
# 0      2698867  September 4, 2023        New York       Brooklyn
# 1      2699049  September 4, 2023         Florida    Casselberry
# 2      2698782  September 3, 2023  North Carolina        Madison
# 3      2698050  September 2, 2023         Arizona       Glendale
# 4      2697322  September 2, 2023        Illinois        Chicago
# 5      2696737  September 1, 2023       Minnesota      Crosslake
# 6      2696519  September 1, 2023         Florida    Tallahassee
# 7      2697720  September 1, 2023       Louisiana     Shreveport
# 8      2696701    August 31, 2023       Wisconsin      Milwaukee
# 9      2696508    August 31, 2023  North Carolina    Statesville
#
#                            Address  Victims Killed  Victims Injured  \
# 0    Eastern Pkwy and Franklin Ave               0                0
# 1           30 block of Jackson Ct               0                2
# ...

# %% [markdown]
# ### Loading XLSL Files

# %% [markdown]
# #### XLSL file #1
#
# ##### **Description of XLSL file:** All lottery mega millions winning numbers, mega ball, and draw dates since 2002.
#
#
# | Columns |  |
# |---|---|
# | Draw Date|  |
# |  Winning Numbers| |
# | Mega Ball  | |
# |  Multiplier|  |
# |  |  |
# |  |  |
# |  |  |
# |  |  |
# |  |  |
# |  |  |

# %%
#  XLSL file #1
# Loading XLSL file #1

dataset3 = pd.read_excel('/Lottery_Mega_Millions_Winning_Numbers__Beginning_2002.xls')
dataset3.head(10)
# Out:
#    Draw Date Winning Numbers  Mega Ball  Multiplier
# 0 2020-09-25  20 36 37 48 67         16         2.0
# 1 2020-09-29  14 39 43 44 67         19         3.0
# 2 2020-10-02  09 38 47 49 68         25         2.0
# 3 2020-10-06  15 16 18 39 59         17         3.0
# 4 2020-10-09  05 11 25 27 64         13         2.0
# 5 2020-10-13  11 44 45 46 70         25         2.0
# 6 2020-10-16  27 32 50 52 57         12         5.0
# 7 2020-10-20  46 54 57 58 66         10         3.0
# 8 2020-10-23  18 34 44 60 69         22         2.0
# 9 2020-10-27  06 13 34 46 62          1         3.0

# %% [markdown]
# #### XLSL File 2
#
# ##### **Description of XLSL file:** The diagnosis code lists are derived from ICD-10 diagnosis codes that CMS posts each year so that providers and suppliers utilize the applicable diagnosis codes when submitting medical claims to Medicare.
#
# | Columns |  |
# |---|---|
# | Code|  |
# |  Short Description| |
# | Long Description  | |
# |  |  |
# |  |  |
# |  |  |
# |  |  |
# |  |  |
# |  |  |
# |  |  |

# %%
#  XLSL file #2
# Loading XLSL file #2

dataset4 = pd.read_excel('/CMS_ICD_10_List.xlsx')
dataset4.head(10)
# Out:
#     CODE            SHORT DESCRIPTION (VALID ICD-10 FY2023)  \
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis
# 5  A0102               Typhoid fever with heart involvement
# 6  A0103                                  Typhoid pneumonia
# 7  A0104                                  Typhoid arthritis
# 8  A0105                              Typhoid osteomyelitis
# 9  A0109             Typhoid fever with other complications
#
#               LONG DESCRIPTION (VALID ICD-10 FY2023) NF EXCL
# 0  Cholera due to Vibrio cholerae 01, biovar chol...     NaN
# 1    Cholera due to Vibrio cholerae 01, biovar eltor     NaN
# 2                               Cholera, unspecified     NaN
# ...

# %% [markdown]
# #### XLSL File 3
#
# ##### **Description of XLSL file:** This dataset covers total population, urban-rural distributions, life expectancy, birth and death rates, fertility rate, infant mortality rate, and growth rate.
#
# | Columns |  |
# |---|---|
# | Country|  |
# | Year | |
# |  Total Population | |
# | Urban Population |  |
# | Rural Population |  |
# |  Population density |  |
# | Life Expectancy  |  |
# | Birth Rate  |  |
# | Death Rate  |  |
# | Fertility Rate  |  |
# |Infant Mortality Rate |||
# |Growth Rate|||

# %%
dataset5 = pd.read_excel('/Global_population_trends.xls')
dataset5.head(10)
# Out:
#        Country  Year Total Population Urban Population Rural Population  \
# 0  Afghanistan  2017                -                -                -
# 1  Afghanistan  2018         36686784          9353296         27333488
# 2  Afghanistan  2019         37769499          9727157         28042342
# 3  Afghanistan  2020         38972230         10142913         28829317
# 4  Afghanistan  2021         40099462         10551772         29547690
# 5      Albania  2017                -                -                -
# 6      Albania  2018          2866376          1728969          1137407
# 7      Albania  2019          2854191          1747593          1106598
# 8      Albania  2020          2837849          1762645          1075204
# 9      Albania  2021          2811666          1770478          1041188
#
#   Population Density Life Expectancy  Birth Rate  Death Rate Fertility Rate  \
# 0                 55              63      37.342       7.027          5.129
# ...

# %% [markdown]
# ### Loading JSON Files

# %% [markdown]
# #### JSON file #1
#
# ##### **Description of XLSL file:** The Opioid Treatment Program (OTP) Providers dataset provides information on Providers who have enrolled in Medicare under the Opioid Treatment Program. It contains provider's name, National Provider Identifier (NPI), address, phone number and the effective enrollment date.
#
#
# | Columns |  |
# |---|---|
# | National Provider Identifier (NPI)|  |
# |  Provider Name| |
# |  Address Line 1  | |
# | Address Line 2 |  |
# | City  |  |
# |State  |  |
# |  Zip Code|  |
# | Medicare ID Effective Date |  |
# | Phone Number |  |
# |  |  |

# %%
#  JSON file #1
# Loading JSON file #1


dataset6 = pd.read_json('/Opiod_dataset.json')

dataset6.head(10)
# Out:
#                      NPI                        PROVIDER NAME  \
# 0  1003081399 1013055110  BAART BEHAVIORAL HEALTH SERVICES IN
# 1             1003150004                 AMS OF WISCONSIN LLC
# 2             1003362484                         BHG XLII LLC
# 3             1003368945                         RTS EDGEWOOD
# 4             1003571647        METRO TREATMENT OF FLORIDA LP
# 5  1003581174 1326713314            PREMIER CARE OF OHIO, LLC
# 6             1003583733  AFFINITY HEALTHCARE GROUP CHERRY HI
# 7             1003947193  WEST TEXAS COUNSELING & REHABILITAT
# 8             1003953548             ALLIANCE RECOVERY CENTER
# 9             1003953548             ALLIANCE RECOVERY CENTER
#
#               ADDRESS LINE 1                  ADDRESS LINE 2            CITY  \
# 0            617 COMSTOCK RD                           STE 5          BERLIN
# 1      9532 E 16 FRONTAGE RD                         STE 100        ONALASKA
# ...

# %% [markdown]
# #### JSON file #2
#
# ##### **Description of JSON file:** The Medicare Inpatient Hospitals by Provider and Service dataset provides information on inpatient discharges for Original Medicare Part A beneficiaries by IPPS hospitals. It includes information on the use, payment, and hospital charges for more than 3,000 U.S. hospitals that received IPPS payments. The data are organized by hospital and Medicare Severity Diagnosis Related Group (DRG).
#
#
# | Columns |  |
# |---|---|
# | CMS Certification numbe|  |
# |Organization Name  | |
# |  City  | |
# | Street|  |
# | Federal Information Processing Standard (FIPS) |  |
# | Zip Code |  |
# |  State Abbreviation |  |
# |  RUCA|  |
# | RUCA Description |  |
# | DRG_Cd |  |
# | DRG_desc |  |
# | Total Discharges |  |
# | Avg_Submtd_Cvrd_Chrg |  |
# | Average Total Payment Amount |  |
# | Average Medicare Payment Amount |  |
# |  |  |

# %%
#  JSON file #2
# Loading JSON file #2

dataset7 = pd.read_json('/Medicare_Inpatient_Hospitals.json')

dataset7.head(10)
# Out:
#    Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name Rndrng_Prvdr_City  \
# 0             10001  Southeast Health Medical Center            Dothan
# 1             10001  Southeast Health Medical Center            Dothan
# 2             10001  Southeast Health Medical Center            Dothan
# 3             10001  Southeast Health Medical Center            Dothan
# 4             10001  Southeast Health Medical Center            Dothan
# 5             10001  Southeast Health Medical Center            Dothan
# 6             10001  Southeast Health Medical Center            Dothan
# 7             10001  Southeast Health Medical Center            Dothan
# 8             10001  Southeast Health Medical Center            Dothan
# 9             10001  Southeast Health Medical Center            Dothan
#
#           Rndrng_Prvdr_St  Rndrng_Prvdr_State_FIPS  Rndrng_Prvdr_Zip5  \
# 0  1108 Ross Clark Circle                        1              36301
# ...

# %% [markdown]
# #### JSON file #3
#
# ##### **Description of JSON file:** The Medicare COVID-19 Cases & Hospitalizations data provides COVID-19 cases and hospitalizations data for Medicare beneficiaries diagnosed with COVID-19.
#
#
#
#
# | Columns | Descriptions  |
# |---|---|
# | Claims_Thru_Dt  | Last date of service associated with the claims included in the report. |
# | Measure_Level | Categories of various measures|
# |  Measure_Element | Age|
# | Measure_Unit| A count of Medicare beneficiaries with a diagnosis of COVID-19 on a claim |
# | Value | Total payment associated with COVID-19 cases for the measurement level, measurement element, and measurement unit.|
# |  |  |
# |  |  |
# |  |  |
# |  |  |

# %%
#  JSON file #3
# Loading JSON file #3

dataset8 = pd.read_json('/Medicare COVID19_Cases_Hospitalizations.json')
dataset8.head(10)
# Out:
#   Claims_Thru_Dt                Measure_Level Measure_Element  \
# 0     02/20/2021               COVID-19 Cases         Overall
# 1     02/20/2021               COVID-19 Cases         Overall
# 2     02/20/2021  COVID-19 Cases by Age Group           65-74
# 3     02/20/2021  COVID-19 Cases by Age Group           65-74
# 4     02/20/2021  COVID-19 Cases by Age Group           75-84
# 5     02/20/2021  COVID-19 Cases by Age Group           75-84
# 6     02/20/2021  COVID-19 Cases by Age Group     85 And Over
# 7     02/20/2021  COVID-19 Cases by Age Group     85 And Over
# 8     02/20/2021  COVID-19 Cases by Age Group    Less Than 65
# 9     02/20/2021  COVID-19 Cases by Age Group    Less Than 65
#
#                  Measure_Unit    Value
# 0           Beneficiary Count  3860957
# 1  Beneficiary Count per 100K     6144
# 2           Beneficiary Count  1473512
# 3  Beneficiary Count per 100K     5031
# 4           Beneficiary Count  1145747
# 5  Beneficiary Count per 100K     6314
# ...
